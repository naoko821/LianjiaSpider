# %%
import pandas as pd
imgfilename = 'table.png'
import numpy as np
import os
import datetime

import matplotlib.pyplot as plt
import matplotlib
from matplotlib import gridspec
from pypinyin import pinyin
import numpy as np
from matplotlib.cbook import get_sample_data

from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg

# %%
gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
ax0 = plt.subplot(gs[0])
ax0.plot(np.sin(range(10)))
ax0.plot(np.sin(range(0,20,2)))

x1,x2,y1,y2 = ax0.axis()

arr_lena = mpimg.imread('wechatqrcode.jpg')

imagebox = OffsetImage(arr_lena, zoom=0.2)

ab = AnnotationBbox(imagebox, (1, -1))

ax0.add_artist(ab)

ax1 = plt.subplot(gs[1])
ax1.plot(np.cos(range(10)))

plt.draw()
plt.savefig('test.png')
plt.show()

# %%
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, ax = plt.subplots()

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

arr_lena = mpimg.imread('/Users/alex/Downloads/wechatqrcode.jpg')

imagebox = OffsetImage(arr_lena, zoom=0.2)

ab = AnnotationBbox(imagebox, (0.4, 0.6))

ax.add_artist(ab)

plt.grid()

plt.draw()
plt.savefig('add_picture_matplotlib_figure.png',bbox_inches='tight')
plt.show()

# %%
from common import plot

# %%
help(AnnotationBbox)
# Out:
# Help on class AnnotationBbox in module matplotlib.offsetbox:
#
# class AnnotationBbox(matplotlib.artist.Artist, matplotlib.text._AnnotationBase)
#  |  Annotation-like class, but with offsetbox instead of Text.
#  |
#  |  Method resolution order:
#  |      AnnotationBbox
#  |      matplotlib.artist.Artist
#  |      matplotlib.text._AnnotationBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, offsetbox, xy, xybox=None, xycoords='data', boxcoords=None, frameon=True, pad=0.4, annotation_clip=None, box_alignment=(0.5, 0.5), bboxprops=None, arrowprops=None, fontsize=None, **kwargs)
#  |      *offsetbox* : OffsetBox instance
#  |
#  |      *xycoords* : same as Annotation but can be a tuple of two
#  |         strings which are interpreted as x and y coordinates.
#  |
#  |      *boxcoords* : similar to textcoords as Annotation but can be a
#  |         tuple of two strings which are interpreted as x and y
#  |         coordinates.
#  |
# ...
