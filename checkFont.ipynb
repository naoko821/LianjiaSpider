# %%
import matplotlib.font_manager
import numpy as np
from IPython.core.display import HTML
matplotlib.font_manager.fontManager.addfont('font/Songti.ttc')
fonts = [f.name for f in matplotlib.font_manager.fontManager.ttflist]
from matplotlib.font_manager import FontProperties
fontSongti=FontProperties(fname='font/Songti.ttc',size=18)
from matplotlib import gridspec
import matplotlib
import matplotlib.pyplot as plt

for font in fonts:
    # Say, "the default sans-serif font is COMIC SANS"
    matplotlib.rcParams['font.sans-serif'] = font
    # Then, "ALWAYS use sans-serif fonts"
    matplotlib.rcParams['font.family'] = "sans-serif"
    x = range(10)
    y = np.sin(x)
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    ax = plt.subplot(gs[1])
    ax.plot(x,y)
    ax.set_xlabel("你好")
    ax.set_ylabel("Median Population")
    print(font)
    ax.set_title(font + "你好", fontsize=20)
    plt.show()
# Out:
# DejaVu Serif
# /home/alex/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/alex/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 22909 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/alex/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/alex/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 22909 missing from current font.
#   font.set_text(s, 0, flags=flags)
# cmss10
# /home/alex/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20320 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
help(matplotlib.font_manager.fontManager.addfont)
# Out:
# Help on method addfont in module matplotlib.font_manager:
#
# addfont(path) method of matplotlib.font_manager.FontManager instance
#     Cache the properties of the font at *path* to make it available to the
#     `FontManager`.  The type of font is inferred from the path suffix.
#
#     Parameters
#     ----------
#     path : str or path-like
