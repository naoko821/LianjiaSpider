# %%
from common import read
bj = read('北京')
# Out:
# /Users/alex/Quant/code/LianjiaSpider/common.py:90: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   df = pd.concat(dfs)
# raw count: 689119
# count after drop duplicates 555179
# count after drop less than 1000 554554
# count after drop 40, 50 535391

# %%
import pandas as pd
from common import plot
bj = bj.dropna(subset=['小区'])

def plotArea(area):
    df = bj.loc[bj['小区'].str.contains(area)]
    gp = df.groupby(['成交时间'])['成交价(元/平)']
    res=pd.DataFrame({"volume":gp.size(),"median_price":gp.median(), "mean_price":gp.mean()})
    res = res.iloc[:len(res),:]
    city = 'default'
    MA = True
    start_date = None
    force = True
    keep_all = True
    for ma_length in [1, 30, 60, 90]:
        title = '%s-%d日均线'%(area, ma_length)
        plot(res, city, title, MA, ma_length, start_date, force, keep_all)

# %%
plotArea('马甸南村')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plotArea('六铺炕')

# %%
df = bj.loc[bj['小区'].str.contains('六铺炕')]
df = df.loc[df['成交时间'] > '2019-07-01'].sort_values('成交时间')
display(df.loc[:,['成交时间','户型','小区', '售价(万)', '建筑面积', '成交价(元/平)','建成时间']])
#df.iloc[4]['网址']
# Out:
#                     成交时间        户型     小区   售价(万)    建筑面积  成交价(元/平)  建成时间
# 链家编号
# 101105056098  2019-07-02  3室1厅1厨1卫  六铺炕二区  1000.0   69.30  144301.0  1983
# 101104341063  2019-07-05  2室1厅1厨1卫  六铺炕二区   838.0   61.70  135819.0  1987
# 101104434522  2019-07-17  2室1厅1厨1卫    六铺炕   565.0   50.34  112237.0  1980
# 101104459677  2019-07-22  3室1厅1厨1卫  六铺炕二区   907.0   92.81   97727.0  1958
# 101105303277  2019-09-05  2室1厅1厨1卫  六铺炕二区   828.0   61.60  134416.0  1990
# 101104900792  2019-09-08  2室1厅1厨1卫  六铺炕三区  1090.0   77.70  140284.0  1999
# 101104412971  2019-09-21  3室1厅1厨1卫  六铺炕二区   954.0   69.00  138261.0  1983
# 101105761474  2019-09-22  3室1厅1厨1卫  六铺炕二区  1150.0   82.70  139057.0  1987
# 101105438858  2019-09-25  2室1厅1厨1卫  六铺炕二区   711.0   56.90  124957.0  1953
# 101105571888  2019-09-30  2室1厅1厨1卫  六铺炕二区   810.0   54.20  149447.0  1983
# 101105345561  2019-09-30  2室1厅1厨1卫  六铺炕二区   934.0   70.40  132654.0  1990
# 101105563273  2019-10-23  3室1厅1厨1卫    六铺炕   935.0   91.19  102534.0  1988
# 101105804796  2019-10-25  3室1厅1厨1卫    六铺炕   655.0   57.93  113068.0  1975
# 101105021087  2019-10-31  2室1厅1厨1卫  六铺炕二区   700.0   60.60  115512.0  1981
# 101104299490  2019-11-02  3室1厅1厨1卫  六铺炕三区  1225.0   94.80  129220.0  1999
# 101105523478  2019-11-05  3室1厅1厨1卫  六铺炕二区  1043.0   78.30  133206.0  1990
# 101105247488  2019-11-08  3室1厅1厨1卫  六铺炕二区   960.0   79.90  120151.0  1981
# 101105247465  2019-11-10  2室1厅1厨1卫  六铺炕二区   862.0   64.30  134060.0  1981
# 101105740858  2019-11-11  3室1厅1厨1卫  六铺炕二区   920.0   67.80  135694.0  1981
# 101103598393  2019-11-17  3室1厅1厨1卫  六铺炕一区  1370.0  104.20  131478.0  1997
# 101105515444  2019-11-21  2室1厅1厨1卫  六铺炕三区   666.0   49.60  134275.0  1954
# 101103870297  2019-11-24  3室1厅1厨1卫  六铺炕二区  1250.0   99.20  126009.0  1994
# 101105770165  2019-11-26  2室0厅1厨1卫  六铺炕二区   750.0   59.30  126476.0  1958
# 101103286985  2019-11-29  2室1厅1厨1卫    六铺炕   530.0   49.67  106705.0  1975
# 101104649509  2019-12-10  2室1厅1厨1卫  六铺炕二区   808.0   62.00  130323.0  1954
# 101106502144  2019-12-16  3室1厅1厨1卫  六铺炕一区  1250.0   91.10  137212.0  1997
# 101106370252  2019-12-16  3室1厅1厨1卫  六铺炕二区   950.0   92.60  102592.0  1953
# 101105654240  2019-12-24  3室1厅1厨1卫  六铺炕一区   902.0   60.90  148112.0  1975
# 101106011115  2019-12-24  2室1厅1厨1卫  六铺炕二区   775.0   53.20  145677.0  1981
# 101104568426  2019-12-31  2室1厅1厨1卫  六铺炕二区   837.0   55.80  150000.0  1981
# 101105191106  2020-01-10  2室1厅1厨1卫  六铺炕一区   955.0   66.50  143610.0  1989
# 101106541426  2020-01-14  2室1厅1厨1卫  六铺炕二区   776.0   53.20  145865.0  1981
# 101105558818  2020-01-16  2室1厅1厨1卫  六铺炕一区  1027.0   72.90  140878.0  1997

# %%
plotArea('新风北街')
